# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# Importing libraries
import folium
import pandas as pd

# %%
# After that, we can immediately set on creating a map
m=folium.Map()

# passing an argument of start location.
m=folium.Map(location=[52.5200, 13.4050],   # the  map view centrepoint. (Berlin).
                zoom_start=12,              # Starting zoom step
                max_zoom=26,                # Maximum zooming step
                min_zoom=10)                 # Minimum zooming step

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5d9afc8acb86a14220e6fc4e2f5b1f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5d9afc8acb86a14220e6fc4e2f5b1f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5d9afc8acb86a14220e6fc4e2f5b1f1 = L.map(
#                 &quot;map_d5d9afc8acb86a14220e6fc4e2f5b1f1&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44a0065637fed42b76e305a0e7249996 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 26, &quot;maxZoom&quot;: 26, &quot;minZoom&quot;: 10, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5d9afc8acb86a14220e6fc4e2f5b1f1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding some markers on interesting areas

# %%
m=folium.Map(location=[52.5200, 13.4050], zoom_start=12, min_zoom=9)

folium.Marker([52.5448, 13.4425]).add_to(m) # Marker at the specified coordinates (Code Academy Berlin)
folium.Marker([52.5168, 13.3775]).add_to(m) # Brandenburger Tor
folium.Marker([52.5118, 13.4445]).add_to(m) # Berghain

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6b40a47c85d823a03f2ba0f3d7688fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6b40a47c85d823a03f2ba0f3d7688fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6b40a47c85d823a03f2ba0f3d7688fb = L.map(
#                 &quot;map_f6b40a47c85d823a03f2ba0f3d7688fb&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb72be9036d1ec89765ffffdbdf3f6ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f6b40a47c85d823a03f2ba0f3d7688fb);
#
#
#             var marker_592297ead7b3524827612f47dd156865 = L.marker(
#                 [52.5448, 13.4425],
#                 {}
#             ).addTo(map_f6b40a47c85d823a03f2ba0f3d7688fb);
#
#
#             var marker_d6f353d50b05cdf34eff2bb736531396 = L.marker(
#                 [52.5168, 13.3775],
#                 {}
#             ).addTo(map_f6b40a47c85d823a03f2ba0f3d7688fb);
#
#
#             var marker_c7ec3a614bf93bf5a5cedb8ba250fa90 = L.marker(
#                 [52.5118, 13.4445],
#                 {}
#             ).addTo(map_f6b40a47c85d823a03f2ba0f3d7688fb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adding text on Map to be more informative

# %%
m=folium.Map(location=[52.5200, 13.4050], zoom_start=12, min_zoom=9)

folium.Marker([52.5448, 13.4425], popup="Code Academy Berlin").add_to(m)
folium.Marker([52.5168, 13.3775], popup="Brandenburger Tor").add_to(m)
folium.Marker([52.5118, 13.4445], popup="Berghain").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b5f03fea2b37906606f702efff43fec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b5f03fea2b37906606f702efff43fec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b5f03fea2b37906606f702efff43fec = L.map(
#                 &quot;map_8b5f03fea2b37906606f702efff43fec&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48bb5920b82b1bb6c2e81abf31bee5c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b5f03fea2b37906606f702efff43fec);
#
#
#             var marker_e0ccedd21b72b94fa4f2de70c97c92c0 = L.marker(
#                 [52.5448, 13.4425],
#                 {}
#             ).addTo(map_8b5f03fea2b37906606f702efff43fec);
#
#
#         var popup_cf79d1d5171e5d07c9906b4401b3d0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_654883a65e6ba6b145f89c172dbb3c18 = $(`&lt;div id=&quot;html_654883a65e6ba6b145f89c172dbb3c18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Code Academy Berlin&lt;/div&gt;`)[0];
#                 popup_cf79d1d5171e5d07c9906b4401b3d0bc.setContent(html_654883a65e6ba6b145f89c172dbb3c18);
#
#
#
#         marker_e0ccedd21b72b94fa4f2de70c97c92c0.bindPopup(popup_cf79d1d5171e5d07c9906b4401b3d0bc)
#         ;
#
#
#
#
#             var marker_f50e90d819d238630f0d805c6567b762 = L.marker(
#                 [52.5168, 13.3775],
#                 {}
#             ).addTo(map_8b5f03fea2b37906606f702efff43fec);
#
#
#         var popup_ce6c328585957ac78dcf3f9ac0d54e8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86277eac9277c72a15f42973515c7065 = $(`&lt;div id=&quot;html_86277eac9277c72a15f42973515c7065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brandenburger Tor&lt;/div&gt;`)[0];
#                 popup_ce6c328585957ac78dcf3f9ac0d54e8c.setContent(html_86277eac9277c72a15f42973515c7065);
#
#
#
#         marker_f50e90d819d238630f0d805c6567b762.bindPopup(popup_ce6c328585957ac78dcf3f9ac0d54e8c)
#         ;
#
#
#
#
#             var marker_16e2f7ecc483f62368391af1d5b8cd28 = L.marker(
#                 [52.5118, 13.4445],
#                 {}
#             ).addTo(map_8b5f03fea2b37906606f702efff43fec);
#
#
#         var popup_1b28a2a484e43f97698d6802c56ec684 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c90344f8b577c724c2114d3515a42792 = $(`&lt;div id=&quot;html_c90344f8b577c724c2114d3515a42792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berghain&lt;/div&gt;`)[0];
#                 popup_1b28a2a484e43f97698d6802c56ec684.setContent(html_c90344f8b577c724c2114d3515a42792);
#
#
#
#         marker_16e2f7ecc483f62368391af1d5b8cd28.bindPopup(popup_1b28a2a484e43f97698d6802c56ec684)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Making the Text to be accessible

# %%
m=folium.Map(location=[52.5200, 13.4050], zoom_start=12, min_zoom=9)

tools="Click here for more info!"

folium.Marker([52.5448, 13.4425],
                popup="<b>Code Academy Berlin</b>",
                tooltip=tools).add_to(m)

folium.Marker([52.5168, 13.3775],
                popup="<i>Brandenburger Tor</i>",
                tooltip=tools).add_to(m)

folium.Marker([52.5118, 13.4445],
                popup="<u>Berghain</u>",
                tooltip=tools).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0018682422b1429fabced379d5fe2b96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0018682422b1429fabced379d5fe2b96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0018682422b1429fabced379d5fe2b96 = L.map(
#                 &quot;map_0018682422b1429fabced379d5fe2b96&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ced3629d9eab5f0cc322602bda80709d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0018682422b1429fabced379d5fe2b96);
#
#
#             var marker_e65a48f7192eee1ac601ee5d6831263c = L.marker(
#                 [52.5448, 13.4425],
#                 {}
#             ).addTo(map_0018682422b1429fabced379d5fe2b96);
#
#
#         var popup_6de2e57d4d42471f7e6549129e5018c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00a170661ee4dc34e49251c611a4bee0 = $(`&lt;div id=&quot;html_00a170661ee4dc34e49251c611a4bee0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Code Academy Berlin&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_6de2e57d4d42471f7e6549129e5018c5.setContent(html_00a170661ee4dc34e49251c611a4bee0);
#
#
#
#         marker_e65a48f7192eee1ac601ee5d6831263c.bindPopup(popup_6de2e57d4d42471f7e6549129e5018c5)
#         ;
#
#
#
#
#             marker_e65a48f7192eee1ac601ee5d6831263c.bindTooltip(
#                 `&lt;div&gt;
#                      Click here for more info!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e214fb42618ead33ab09643bc3218bc8 = L.marker(
#                 [52.5168, 13.3775],
#                 {}
#             ).addTo(map_0018682422b1429fabced379d5fe2b96);
#
#
#         var popup_cd5b65cbbeffaf6a4a05b2a9f809d1cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe65d197f2b1f72effde9a405cad5864 = $(`&lt;div id=&quot;html_fe65d197f2b1f72effde9a405cad5864&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Brandenburger Tor&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_cd5b65cbbeffaf6a4a05b2a9f809d1cd.setContent(html_fe65d197f2b1f72effde9a405cad5864);
#
#
#
#         marker_e214fb42618ead33ab09643bc3218bc8.bindPopup(popup_cd5b65cbbeffaf6a4a05b2a9f809d1cd)
#         ;
#
#
#
#
#             marker_e214fb42618ead33ab09643bc3218bc8.bindTooltip(
#                 `&lt;div&gt;
#                      Click here for more info!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f75498afc86fc20ef0e29856d2c39b5b = L.marker(
#                 [52.5118, 13.4445],
#                 {}
#             ).addTo(map_0018682422b1429fabced379d5fe2b96);
#
#
#         var popup_b450d500d27e41ce4e028a4640e7e3bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd0fa256d0fac2317f377ba3e4cc5e0e = $(`&lt;div id=&quot;html_bd0fa256d0fac2317f377ba3e4cc5e0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;u&gt;Berghain&lt;/u&gt;&lt;/div&gt;`)[0];
#                 popup_b450d500d27e41ce4e028a4640e7e3bd.setContent(html_bd0fa256d0fac2317f377ba3e4cc5e0e);
#
#
#
#         marker_f75498afc86fc20ef0e29856d2c39b5b.bindPopup(popup_b450d500d27e41ce4e028a4640e7e3bd)
#         ;
#
#
#
#
#             marker_f75498afc86fc20ef0e29856d2c39b5b.bindTooltip(
#                 `&lt;div&gt;
#                      Click here for more info!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Customization of the markers

# %%
m=folium.Map(location=[52.5200, 13.4050], zoom_start=12, min_zoom=9)

tools="Click here for more info!"

folium.Marker([52.5448, 13.4425], popup="<b>Code Academy Berlin</b>",
                tooltip=tools,
                icon=folium.Icon(icon="cloud",            # Change the marker to a cloud 
                                color="green")).add_to(m) # Colour it green

folium.CircleMarker([52.5168, 13.3775], popup="<b>Brandenburger Tor</b>",
                tooltip=tools,
                radius=10,                    # Radius in metres
                color="crimson",              # Colour of the circle's perimeter
                fill=True,                    # Whether or not to fill the inside of the circle
                fill_color="black").add_to(m) # Colour to fill the circle

folium.Circle([52.5118, 13.4445], popup="<b>Berghain</b>",
                tooltip=tools,
                radius=1000,
                color="black",
                fill=True,
                fill_color="crimson").add_to(m)

m
# Circle and CircleMarker are similar, with their only difference being that CircleMarker radius is measured in meters while
# Circle radius is measured in pixels. Therefore Circle radius stays at a fixed size independent of zoom level.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffad65425dd3bf53a49df7a20fad12b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffad65425dd3bf53a49df7a20fad12b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffad65425dd3bf53a49df7a20fad12b3 = L.map(
#                 &quot;map_ffad65425dd3bf53a49df7a20fad12b3&quot;,
#                 {
#                     center: [52.52, 13.405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea39243faa63d321b2cbdcb716c4fd15 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ffad65425dd3bf53a49df7a20fad12b3);
#
#
#             var marker_2bff8a319e8e6a4ac460ded83e1744f7 = L.marker(
#                 [52.5448, 13.4425],
#                 {}
#             ).addTo(map_ffad65425dd3bf53a49df7a20fad12b3);
#
#
#             var icon_386565d1284d85a40ec3db42ac99089d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bff8a319e8e6a4ac460ded83e1744f7.setIcon(icon_386565d1284d85a40ec3db42ac99089d);
#
#
#         var popup_9bb816e4a86819ad35a92aa89cb48ce6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cad89b1c4a767ed73afaa6dfa9d83a23 = $(`&lt;div id=&quot;html_cad89b1c4a767ed73afaa6dfa9d83a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Code Academy Berlin&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_9bb816e4a86819ad35a92aa89cb48ce6.setContent(html_cad89b1c4a767ed73afaa6dfa9d83a23);
#
#
#
#         marker_2bff8a319e8e6a4ac460ded83e1744f7.bindPopup(popup_9bb816e4a86819ad35a92aa89cb48ce6)
#         ;
#
#
#
#
#             marker_2bff8a319e8e6a4ac460ded83e1744f7.bindTooltip(
#                 `&lt;div&gt;
#                      Click here for more info!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3bfb8f04abf1c61400f417510e78f3d6 = L.circleMarker(
#                 [52.5168, 13.3775],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffad65425dd3bf53a49df7a20fad12b3);
#
#
#         var popup_d62335f384f6e5949a22af606e6ea698 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72dc4153f5ea98c3bec8e88c0f5c6d42 = $(`&lt;div id=&quot;html_72dc4153f5ea98c3bec8e88c0f5c6d42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Brandenburger Tor&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_d62335f384f6e5949a22af606e6ea698.setContent(html_72dc4153f5ea98c3bec8e88c0f5c6d42);
#
#
#
#         circle_marker_3bfb8f04abf1c61400f417510e78f3d6.bindPopup(popup_d62335f384f6e5949a22af606e6ea698)
#         ;
#
#
#
#
#             circle_marker_3bfb8f04abf1c61400f417510e78f3d6.bindTooltip(
#                 `&lt;div&gt;
#                      Click here for more info!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_abcf4d575b5d606fc5abf7eb91c4ce86 = L.circle(
#                 [52.5118, 13.4445],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffad65425dd3bf53a49df7a20fad12b3);
#
#
#         var popup_be741a6ece215c2c191c8789a4ab81af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42c70d36a6aaa7c6f65a4992409072ef = $(`&lt;div id=&quot;html_42c70d36a6aaa7c6f65a4992409072ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Berghain&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_be741a6ece215c2c191c8789a4ab8

# %% [markdown]
# Marking and showcasing some countries

# %%
import json
with open (r'world_countries.json') as i:
    countries = json.loads(i.read())

# The list that we loaded contains all the countries in the world. For the
# sake of this example, we will choose some specific ones.
country_list = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus",
                "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
                "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania",
                "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal",
                "Romania", "Slovakia", "Slovenia", "Spain", "Sweden"]

# The map we will be using, Choropleth, is designed for heatmaps, or colour-scale maps.
# Unless we add a second column to our dataframe, to serve as the hue of the map, we can not plot it.
country_list = pd.DataFrame(country_list, columns=["name"])
country_list["GDP"]=0

# Create the map
m = folium.Map(location=[54,20], zoom_start=4)

# Plot our selected countries
i = folium.Choropleth(geo_data=countries,                 # The data source for the polygon shapes and coordinates
                        data=country_list,                # The data source for the countries we want to show
                        columns=["name", "GDP"],          # Column labels for data
                        key_on="feature.properties.name", # How to join geo_data and data. Requires the dictionary key from geo_data
                        fill_color="YlGn",                # Defines which colour scale to use
                        nan_fill_opacity=0,               # Set this argument to 0 if we do not want to shade countries outside of our list.
                        name="EU Countries",              # Name for the map overlay
                        show=True                         # Whether or not the overlay will show by default
                        ).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import json
# ----> 2 with open (r'world_countries.json') as i:
#       3     countries = json.loads(i.read())
#       5 # The list that we loaded contains all the countries in the world. For the
#       6 # sake of this example, we will choose some specific ones.
#
# File c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'world_countries.json'

# %% [markdown]
# Displaying country names at hovering

# %%
# In order to achieve that we will create a new dataframe with relevant information
country= ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus",
                "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
                "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania",
                "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal",
                "Romania", "Slovakia", "Slovenia", "Spain", "Sweden"]
gdp = [471, 579, 89.04, 70.96, 28.44, 291, 395, 38.1, 281, 2783, 4072, 219, 179,
       529, 2010, 41.15, 70.33, 82.27, 17.77, 991, 688, 252, 301, 115, 62.12, 1398, 586]
country_list = pd.DataFrame(list(zip(country, gdp)), columns=["Country", "GDP"])

# Plot the map as we did before
m = folium.Map(location=[51,10], zoom_start=3)
i = folium.Choropleth(geo_data=countries, data=country_list, columns=["Country", "GDP"],
                      key_on="feature.properties.name", fill_color="YlGn",
                      nan_fill_opacity=0, name="EU Countries", show=True).add_to(m)

# First we need to set the country names as index in our dataframe
# Then we need to add the values we wat to display, in our case column tempo
# inside the countries dictionary.
country_list=country_list.set_index("Country")
for s in i.geojson.data["features"]:
    try:
        s["properties"]["gdp"]="{:,}".format(round(country_list.at[s["properties"]["name"],"GDP"]))
    except KeyError:
        s["properties"]["gdp"]=0

# Now we add the hovering tooltip
folium.GeoJsonTooltip(fields=["name", "gdp"],   # The columns from which to draw data for displaying on hover over
aliases=["Country:", "GDP(2022) in $B:"]        # How to "rename" the column labels for display purposes
).add_to(i.geojson)
m.add_child(folium.LayerControl())

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 13
#      11 # Plot the map as we did before
#      12 m = folium.Map(location=[51,10], zoom_start=3)
# ---> 13 i = folium.Choropleth(geo_data=countries, data=country_list, columns=["Country", "GDP"],
#      14                       key_on="feature.properties.name", fill_color="YlGn",
#      15                       nan_fill_opacity=0, name="EU Countries", show=True).add_to(m)
#      17 # First we need to set the country names as index in our dataframe
#      18 # Then we need to add the values we wat to display, in our case column tempo
#      19 # inside the countries dictionary.
#      20 country_list=country_list.set_index("Country")
#
# NameError: name 'countries' is not defined

# %%
# For simplicity's sake, we will stick with the EU data, and add an overlay for each country's population.

country= ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus",
                "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany",
                "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania",
                "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal",
                "Romania", "Slovakia", "Slovenia", "Spain", "Sweden"]

gdp = [471, 579, 89.04, 70.96, 28.44, 291, 395, 38.1, 281, 2783, 4072, 219, 179,
       529, 2010, 41.15, 70.33, 82.27, 17.77, 991, 688, 252, 301, 115, 62.12, 1398, 586]

population = [9104772, 11754004, 6447710, 3850894, 920701, 10827529, 5932654, 1365884,
              5563970, 68070697, 84358845, 10394055, 9597085, 5194336, 58850717,
              1883008, 2857279, 660809, 542051, 17811291, 36753736, 10467366,
              19051562, 5428792, 2116792, 48059777, 10521556]

country_list = pd.DataFrame(list(zip(country, gdp, population)), columns=["country", "gdp", "pop"])

# Plot the map once more
m = folium.Map(location=[54,10], zoom_start=4)

# For each seperate overlay we want to be displayed we have to create a seperate Choropleth object.
# In our case, it will be i1 for the GDP overlay and i2 for the population overlay.
i1 = folium.Choropleth(geo_data=countries,
                        data=country_list,
                        columns=["country", "gdp"],
                        key_on="feature.properties.name",
                        fill_color="YlGn",
                        nan_fill_opacity=0,
                        name="EU Countries GDP",
                        show=False
                        ).add_to(m)

i2 = folium.Choropleth(geo_data=countries,
                        data=country_list,
                        columns=["country", "pop"],
                        key_on="feature.properties.name",
                        fill_color="RdBu",
                        nan_fill_opacity=0,
                        name="EU Countries population",
                        show=True
                        ).add_to(m)

# Again, pass the GDP and population information to the countries dictionary
country_list=country_list.set_index("country")
for s in i.geojson.data["features"]:
    try:
        s["properties"]["gdp"]="{:,}".format(round(country_list.at[s["properties"]["name"],"gdp"]))
    except KeyError:
        s["properties"]["gdp"]=0
    try:
        s["properties"]["pop"]="{:,}".format(round(country_list.at[s["properties"]["name"], "pop"] / 1000))
    except KeyError:
        s["properties"]["pop"]=0

# Add the GDP overlay
folium.GeoJsonTooltip(fields=["name", "gdp"], aliases=["Country:", "GDP(2022) in $B:"]).add_to(i1.geojson)

# Add the population overlay
folium.GeoJsonTooltip(fields=["name", "pop"], aliases=["Country:", "Population(2022) in thousands:"]).add_to(i2.geojson)

m.add_child(folium.LayerControl())

m

# %%
m = folium.Map((0, 0), zoom_start=7)

group_1 = folium.FeatureGroup("first group").add_to(m)
folium.Marker((0, 0), icon=folium.Icon("red")).add_to(group_1)
folium.Marker((1, 0), icon=folium.Icon("red")).add_to(group_1)

group_2 = folium.FeatureGroup("second group").add_to(m)
folium.Marker((0, 1), icon=folium.Icon("green")).add_to(group_2)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb4c376afea76479c1e7da17b8de51b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb4c376afea76479c1e7da17b8de51b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb4c376afea76479c1e7da17b8de51b6 = L.map(
#                 &quot;map_bb4c376afea76479c1e7da17b8de51b6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6e9a479a52edd4dca62eea0fd47d59e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb4c376afea76479c1e7da17b8de51b6);
#
#
#             var feature_group_084ec2b404e61279125de2be1a5a341b = L.featureGroup(
#                 {}
#             ).addTo(map_bb4c376afea76479c1e7da17b8de51b6);
#
#
#             var marker_eb47b12d008a618734a9ebc81cb64ac5 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(feature_group_084ec2b404e61279125de2be1a5a341b);
#
#
#             var icon_dab6b4d9cc2a59e270f2857d603604e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb47b12d008a618734a9ebc81cb64ac5.setIcon(icon_dab6b4d9cc2a59e270f2857d603604e2);
#
#
#             var marker_e244b8a66506acee0a7efb202500e33c = L.marker(
#                 [1.0, 0.0],
#                 {}
#             ).addTo(feature_group_084ec2b404e61279125de2be1a5a341b);
#
#
#             var icon_fdbae571c5e163d1ba2fe095e7dd2c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e244b8a66506acee0a7efb202500e33c.setIcon(icon_fdbae571c5e163d1ba2fe095e7dd2c6c);
#
#
#             var feature_group_4c99e95332d4bf087d873ca9524f5ec4 = L.featureGroup(
#                 {}
#             ).addTo(map_bb4c376afea76479c1e7da17b8de51b6);
#
#
#             var marker_da66704910596b7eb68fc7761364a7be = L.marker(
#                 [0.0, 1.0],
#                 {}
#             ).addTo(feature_group_4c99e95332d4bf087d873ca9524f5ec4);
#
#
#             var icon_619f5a79c4e4fbc0f73e1d7dcaeb2ca9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da66704910596b7eb68fc7761364a7be.setIcon(icon_619f5a79c4e4fbc0f73e1d7dcaeb2ca9);
#
#
#             var layer_control_405b52553c596fa7059bbf7dc85d893c = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e6e9a479a52edd4dca62eea0fd47d59e,
#                 },
#                 overlays :  {
#                     &quot;first group&quot; : feature_group_084ec2b404e61279125de2be1a5a341b,
#                     &quot;second group&quot; : feature_group_4c99e95332d4bf087d873ca9524f5ec4,
#                 },
#             };
#             L.control.layers(
#                 layer_control_405b52553c596fa7059bbf7dc85d893c.base_layers,
#                 layer_control_405b52553c596fa7059bbf7dc85d893c.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_bb4c376afea76479c1e7da17b8de51b6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
